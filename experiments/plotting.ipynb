# %% [markdown]
# ## Stride Scheduling (8:4:2:1) Ticket allocation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user
time_quanta = np.array([20, 40, 60, 80, 100])

# Actual data (Avg)
actual = {
    'A': np.array([10, 21.2, 32, 42, 53]),
    'B': np.array([5, 10.8, 16, 21, 27]),
    'C': np.array([3, 5, 8, 11, 13]),
    'D': np.array([2, 3, 4, 6, 7])
}

# Expected data
expected = {
    'A': np.array([10, 20, 30, 40, 50]),
    'B': np.array([5, 10, 15, 20, 25]),
    'C': np.array([3, 6, 9, 12, 15]),
    'D': np.array([2, 4, 6, 8, 10])
}

colors = {'A': 'red', 'B': 'green', 'C': 'blue', 'D': 'orange'}

plt.figure(figsize=(8,6))

# Plot actual data as solid lines with labels (just A, B, C, D)
for client, vals in actual.items():
    plt.plot(time_quanta, vals, color=colors[client], label=client, marker='o')

# Plot expected data as dashed gray lines, only label the first one
for i, vals in enumerate(expected.values()):
    if i == 0:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed', label='Expected')
    else:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed')

plt.xlabel('Time (quanta)')
plt.ylabel('Cumulative Quanta')
plt.title('Stride Scheduling (8:4:2:1) Ticket allocation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stride Scheduling (1:1:1:1) Ticket allocation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user
time_quanta = np.array([20, 40, 60, 80, 100])

# Actual data (Avg)
actual = {
    'A': np.array([5, 10, 15, 20, 25]),
    'B': np.array([5, 10, 15, 20, 25]),
    'C': np.array([5, 10, 15, 20, 25]),
    'D': np.array([5, 10, 15, 20, 25])
}

# Expected data
expected = {
    'A': np.array([5, 10, 15, 20, 25]),
    'B': np.array([5, 10, 15, 20, 25]),
    'C': np.array([5, 10, 15, 20, 25]),
    'D': np.array([5, 10, 15, 20, 25])
}

colors = {'A': 'red', 'B': 'green', 'C': 'blue', 'D': 'orange'}

plt.figure(figsize=(8,6))

# Plot actual data as solid lines with labels (just A, B, C, D)
for client, vals in actual.items():
    plt.plot(time_quanta, vals, color=colors[client], label=client, marker='o')

# Plot expected data as dashed gray lines, only label the first one
for i, vals in enumerate(expected.values()):
    if i == 0:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed', label='Expected')
    else:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed')

plt.xlabel('Time (quanta)')
plt.ylabel('Cumulative Quanta')
plt.title('Stride Scheduling (1:1:1:1) Ticket allocation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lottery Scheduling (8:4:2:1) Ticket allocation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user
time_quanta = np.array([20, 40, 60, 80, 100])

# Actual data (Avg)
actual = {
    'A': np.array([10.4, 19.4,	31.8, 40, 59.2]),
    'B': np.array([5.6, 11.2, 16, 21, 22.2]),
    'C': np.array([2.2, 6.6, 7.8, 12.6, 14.2]),
    'D': np.array([1.8, 2.8, 4.4, 6.4, 4.8])
}

# Expected data
expected = {
    'A': np.array([10, 20, 30, 40, 50]),
    'B': np.array([5, 10, 15, 20, 25]),
    'C': np.array([3, 6, 9, 12, 15]),
    'D': np.array([2, 4, 6, 8, 10])
}

colors = {'A': 'red', 'B': 'green', 'C': 'blue', 'D': 'orange'}

plt.figure(figsize=(8,6))

# Plot actual data as solid lines with labels (just A, B, C, D)
for client, vals in actual.items():
    plt.plot(time_quanta, vals, color=colors[client], label=client, marker='o')

# Plot expected data as dashed gray lines, only label the first one
for i, vals in enumerate(expected.values()):
    if i == 0:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed', label='Expected')
    else:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed')
        
plt.xlabel('Time (quanta)')
plt.ylabel('Cumulative Quanta')
plt.title('Lottery Scheduling (8:4:2:1) Ticket allocation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lottery Scheduling (1:1:1:1) Ticket allocation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user
time_quanta = np.array([20, 40, 60, 80, 100])

# Actual data (Avg)
actual = {
    'A': np.array([4.6, 8.6, 13.2, 23.4, 22.6]),
    'B': np.array([5.4, 9.2, 14.2, 18.4, 29]),
    'C': np.array([5.2, 10.2, 17.6, 20.2, 25]),
    'D': np.array([4.8, 12, 15, 18, 23.4])
}

# Expected data
expected = {
    'A': np.array([5, 10, 15, 20, 25]),
    'B': np.array([5, 10, 15, 20, 25]),
    'C': np.array([5, 10, 15, 20, 25]),
    'D': np.array([5, 10, 15, 20, 25])
}

colors = {'A': 'red', 'B': 'green', 'C': 'blue', 'D': 'orange'}

plt.figure(figsize=(8,6))

# Plot actual data as solid lines with labels (just A, B, C, D)
for client, vals in actual.items():
    plt.plot(time_quanta, vals, color=colors[client], label=client, marker='o')

# Plot expected data as dashed gray lines, only label the first one
for i, vals in enumerate(expected.values()):
    if i == 0:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed', label='Expected')
    else:
        plt.plot(time_quanta, vals, color='gray', linestyle='dashed')

plt.xlabel('Time (quanta)')
plt.ylabel('Cumulative Quanta')
plt.title('Lottery Scheduling (1:1:1:1) Ticket allocation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
